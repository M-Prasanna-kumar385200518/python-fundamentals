isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
x=df.iloc[:,:8]
y=df.iloc[:,8]

# %%
x
# Out:
#               ph    Hardness        Solids  Chloramines     Sulfate  \
# 0       7.080795  204.890455  20791.318981     7.300212  368.516441
# 1       3.716080  129.422921  18630.057858     6.635246  333.775777
# 2       8.099124  224.236259  19909.541732     9.275884  333.775777
# 3       8.316766  214.373394  22018.417441     8.059332  356.886136
# 4       9.092223  181.101509  17978.986339     6.546600  310.135738
# ...          ...         ...           ...          ...         ...
# 100493  8.877281  246.101865  21178.737744     7.765320  343.078182
# 100494  7.278621  212.564507  38712.303513     5.798552  262.091710
# 100495  7.379448  267.665887  15815.433781    10.525736  333.737272
# 100496  6.778115  175.896429  21467.765391     7.103072  349.541131
# 100497  7.537867  216.387845   9470.095665     4.987212  341.496198
#
#         Conductivity  Organic_carbon  Trihalomethanes
# 0         564.308654       10.379783        86.990970
# 1         592.885359       15.180013        56.329076
# 2         418.606213       16.868637        66.420093
# 3         363.266516       18.436524       100.341674
# 4         398.410813       11.558279        31.997993
# ...              ...             ...              ...
# 100493    753.380312       16.941735        60.423472
# 100494    332.442841       14.053881        70.343043
# 100495    541.727616       13.361341        54.616800
# 100496    427.190858       12.543752        55.262978
# 100497    501.388906       11.258956        52.974783
#
# [100498 rows x 8 columns]

# %%
y
# Out:
# 0         2.963135
# 1         4.500656
# 2         3.055934
# 3         4.628771
# 4         4.075075
#             ...
# 100493    3.091997
# 100494    4.816059
# 100495    4.730908
# 100496    2.847829
# 100497    3.743973
# Name: Turbidity, Length: 100498, dtype: float64

# %%
seed=42
test_size=0.25
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=test_size,random_state=seed)

# %%
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder

# Encode target variable if it's continuous or non-integer
le = LabelEncoder()
y_train = le.fit_transform(y_train)  # Converts labels to 0, 1, 2, ...

# Initialize and train the model
model = XGBClassifier()
model.fit(x_train, y_train)

# %%
y_pred=model.predict(x_test)
predictions=[round(value) for value in y_pred]
print(predictions)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 y_pred=model.predict(x_test)
#       2 predictions=[round(value) for value in y_pred]
#       3 print(predictions)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xgboost\sklearn.py:1633, in XGBClassifier.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1624 def predict(
#    1625     self,
#    1626     X: ArrayLike,
#    (...)
#    1630     iteration_range: Optional[IterationRange] = None,
#    1631 ) -> ArrayLike:
#    1632     with config_context(verbosity=self.verbosity):
# -> 1633         class_probs = super().predict(
#    1634             X=X,
#    1635             output_margin=output_margin,
#    1636             validate_features=validate_features,
#    1637             base_margin=base_margin,
#    1638             iteration_range=iteration_range,
#    1639         )
#    1640         if output_margin:
#    1641             # If output_margin is active, simply return the scores
#    1642             return class_probs
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xgboost\sklearn.py:1248, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1246 if self._can_use_inplace_predict():
#    1247     try:
# -> 1248         predts = self.get_booster().inplace_predict(
#    1249             data=X,
#    1250             iteration_range=iteration_range,
#    1251             predict_type="margin" if output_margin else "value",
#    1252             missing=self.missing,
#    1253             base_margin=base_margin,
#    1254             validate_features=validate_features,
#    1255         )
#    1256         if _is_cupy_alike(predts):
#    1257             import cupy  # pylint: disable=import-error
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xgboost\sklearn.py:853, in XGBModel.get_booster(self)
#     850 if not self.__sklearn_is_fitted__():
#     851     from sklearn.exceptions import NotFittedError
# --> 853     raise NotFittedError("need to call fit or load_model beforehand")
#     854 return self._Booster
#
# NotFittedError: need to call fit or load_model beforehand

# %%
accuracy=accuracy_score(y_test,predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 76.04%
