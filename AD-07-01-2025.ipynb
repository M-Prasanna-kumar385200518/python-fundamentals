# %%
s={11,22,33,44,55,66}
s.add(77)
print(s)
# Out:
# {33, 66, 22, 55, 11, 44, 77}

# %%
s
# Out:
# {11, 22, 33, 44, 55, 66, 77}

# %%
s.discard(44)
print(s)
# Out:
# {33, 66, 22, 55, 11, 77}

# %%
s
# Out:
# {11, 22, 33, 55, 66, 77}

# %%
s1 = {1, 2, 3}
s2 = {3, 4, 5}
print(s1 | s2) #Union of sets
# Out:
# {1, 2, 3, 4, 5}

# %%
print(s1 & s2) #Intersection of sets
# Out:
# {3}

# %%
print(s1 - s2) #Difference of sets
# Out:
# {1, 2}

# %%
print(s1 ^ s2) #Symmetric difference
# Out:
# {1, 2, 4, 5}

# %%
print(s1 >= s2) #superset
# Out:
# False

# %%
type(s1)
# Out:
# set

# %%
type(s2)
# Out:
# set

# %%
print(s1 <= s2) #Is s1 a subset of s2
# Out:
# False

# %%
print(s1 >= s2)
# Out:
# False

# %%
print(s2 > s1) #Is s2 a proper set of s1
# Out:
# False

# %%
a={1,2,3,4}
lst=list(a)
print(lst)
# Out:
# [1, 2, 3, 4]

# %%
tpl=tuple(a)
print(tpl)
# Out:
# (1, 2, 3, 4)
