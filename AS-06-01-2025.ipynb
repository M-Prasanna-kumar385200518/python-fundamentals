# %%
a=[1,2]
type(a)
# Out:
# list

# %%
a=[973,765,273]
a[1]
# Out:
# 765

# %%
a[2]
# Out:
# 273

# %%
a[0]
# Out:
# 973

# %%
cricket=['Sachin Tendulkar','Sourav Ganguly','Rahul Dravid','VVS Laxman','Virendra Sehwag']

# %%
cricket[0]
# Out:
# 'Sachin Tendulkar'

# %%
cricket[1]
# Out:
# 'Sourav Ganguly'

# %%
cricket[2]
# Out:
# 'Rahul Dravid'

# %%
cricket[3]
# Out:
# 'VVS Laxman'

# %%
cricket[4]
# Out:
# 'Virendra Sehwag'

# %%
a[-1]
# Out:
# 273

# %%
cricket=['Sachin Tendulkar','Sourav Ganguly','Rahul Dravid','VVS Laxman','Virendra Sehwag']
cricket[1:2]
# Out:
# ['Sourav Ganguly']

# %%
cricket[1:4]
# Out:
# ['Sourav Ganguly', 'Rahul Dravid', 'VVS Laxman']

# %%
cricket[-1]
# Out:
# 'Virendra Sehwag'

# %%
scores=[241,200,233,281,319]

# %%
scores[0]
# Out:
# 241

# %%
scores[-1:-1]
# Out:
# []

# %%
scores[-1:-3]
# Out:
# []

# %%
scores[1:-2]
# Out:
# [200, 233]

# %%
scores[0:1]
# Out:
# [241]

# %%
c=scores+cricket
print(c)
# Out:
# [241, 200, 233, 281, 319, 'Sachin Tendulkar', 'Sourav Ganguly', 'Rahul Dravid', 'VVS Laxman', 'Virendra Sehwag']

# %%
c=a
a!=c
print(c)
print(a)
# Out:
# [973, 765, 273]
# [973, 765, 273]

# %%
c!=a
print(c)
# Out:
# [973, 765, 273]

# %%
c==a
print(c)
# Out:
# [973, 765, 273]
