# %%
2+3
# Out:
# 5

# %%
3-2
# Out:
# 1

# %%
a=9
b=9

# %%
a+b
# Out:
# 18

# %%
a-b
# Out:
# 0

# %%
a*b
# Out:
# 81

# %%
a**b
# Out:
# 387420489

# %%
a | b
# Out:
# 9

# %%
a < b
# Out:
# False

# %%
a > b
# Out:
# False

# %%
a == b
# Out:
# True

# %%
a != b
# Out:
# False

# %%
a >> b
# Out:
# 0

# %%
a << b
# Out:
# 4608

# %%
(a > b) and (a > 100)
# Out:
# False

# %%
a = 9
b = 9

result_and = a == 9 and b == 9
result_or = a == 9 or b == 10
result_not = not (a > b)

# %%
result_and
# Out:
# True

# %%
result_or
# Out:
# True

# %%
result_not
# Out:
# True

# %%
a=9
b=9
result1 = a==9 and b==9
result2 = a==9 or b == 10
result3 = not (a >  b)

# %%
result1
# Out:
# True

# %%
result2
# Out:
# True

# %%
result3
# Out:
# True

# %%
type(a)
# Out:
# int

# %%
str(a)
# Out:
# '9'

# %%
float(a)
# Out:
# 9.0

# %%
bool(a)
# Out:
# True

# %%
type(a)
# Out:
# int

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
